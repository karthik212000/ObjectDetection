# %% [markdown]
# Installing library opencv python

# %% [markdown]
# # ***The Spark Foundation - GRIP- MAY2021***

# %% [markdown]
# ## TASK 1- Object Detection

# %% [markdown]
# ### Karthik V **A**

# %% [markdown]
# Installing library opencv python

# %%
pip install opencv-python

# %% [markdown]
# Installing library tensorflow

# %%
pip install tensorflow

# %% [markdown]
# Installing library keras

# %%
pip install keras

# %% [markdown]
# Import libraries

# %%
from keras.applications import ResNet50
from keras.applications import imagenet_utils
from keras.preprocessing.image import img_to_array,load_img
import numpy as np
import cv2

# %%
from google.colab.patches import cv2_imshow

# %% [markdown]
# Read and display the image

# %%
img_path = '/content/imger1.jpg'
img = load_img(img_path)
disp_img = cv2.imread(img_path)
cv2_imshow( disp_img)
# Out:
# <PIL.Image.Image image mode=RGB size=259x194 at 0x7F1CF8E28F90>

# %% [markdown]
# Resize the image

# %%
img = img.resize((224,224))
img_array = img_to_array(img)
#convert the image into 4D
img_array = np.expand_dims(img_array, axis=0)

# %% [markdown]
# Preprocess the input image

# %%
img_array = imagenet_utils.preprocess_input(img_array)

# %% [markdown]
# Load the model and predict the object name

# %%
pretrained_model = ResNet50(weights='imagenet')

#predict using predict()
prediction = pretrained_model.predict(img_array)

#decode the prediction
actual_prediction = imagenet_utils.decode_predictions(prediction)

print("predicted object is")
print(actual_prediction[0][1])
print(actual_prediction[0][4])
# Out:
# predicted object is
# ('n02108422', 'bull_mastiff', 0.06581843)
# ('n02108915', 'French_bulldog', 0.0020178678)
